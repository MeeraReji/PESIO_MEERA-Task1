# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('tested.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6376910294ae> in <module>
# ----> 1 data=pd.read_csv('tested.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
print("the rows and columns are",data.shape)

# %%
data.head(10)

# %%
data.head(10)

# %%
adata=data.head(10)
bdata=data.tail(10)
pd.concat([adata,bdata])

# %%
print("mean of all columns is:",data.mean())

# %%
print("median is:",data.median())

# %%
data.sort_values(by="Fare", ascending=False)

# %%
data.isnull()

# %%
print("to drop column with null value",data.dropna(1))

# %%
data.dropna()

# %%
Arr1 = np.array([1,2,3,2,3,4,3,4,5,6])

# %%
Arr2 = np.array([7,2,10,2,7,4,9,4,9,8])

# %%
Arr1_2d = np.reshape(Arr1, (2, 5))
print(Arr1_2d)
# Out:
# [[1 2 3 2 3]
#  [4 3 4 5 6]]

# %%
Arr1.join(Arr2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-b7353345b618> in <module>
# ----> 1 Arr1.join(Arr2)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'join'

# %%
np.intersect1d(Arr1,Arr2)

# %%
print("the elements present in only array1 is:", np.delete(Arr1,[1,3,5,7]))

# %%
set_diff = np.setdiff1d(Arr1, Arr2)
print("the elements present in only array1 is:", set_diff)

# %%
np.isnan(Arr1)
